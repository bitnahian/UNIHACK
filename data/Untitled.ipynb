# %%
import pandas as pd
import psycopg2 as p
import requests
import json
import time
import sys
import csv

def load_data(filename):
    with open(filename, 'r') as f:
        lines = csv.reader(f)
        return list(lines)


key = "AIzaSyBEKhNMTbBdU1jesASAEdnJc4BWRrFYsyc" # DON'T SHARE WITH ANYONE

base_url = 'https://maps.googleapis.com/maps/api/geocode/json'


if __name__ == '__main__':
    
    df = pd.read_csv('lane_cove.csv')
    
    df["LATITUDE"] = ""
    df["LONGITUDE"] = ""
  
   
    for index, row in df.iterrows(): 
        
        print(row['LOCATION_DETAILS'])
        
#         r[1] = the name of the area for which I want lat and long for.
        my_params= {'address': row['LOCATION_DETAILS'].lower() + ', New South Wales, Australia', 'language':'en','key' : key}
        response = requests.get(base_url, params = my_params)

        results = response.json()
        print(results)

#         nhood_geo = results[0]['geometry']['location']
#         print(nhood_geo)
        

#         #I assign the lat and long found for this area into a dictionary so that we can use it in the next for loop.
#         #If this isn't done, we would've needed to put the for loop written below in here, which causes A LOT of API calls.
#         #That makes the program VERY slow.
#         latNE = nhood_viewport['northeast']['lat']
#         lngNE = nhood_viewport['northeast']['lng']

#         latSW = nhood_viewport['southwest']['lat']
#         lngSW = nhood_viewport['southwest']['lng']

#         dictionary[r[0]] = [latNE, lngNE, latSW, lngSW]

#     #List to hold the [pod_id, area_id] pair
#     new_list = []        

#     for r in car_rows:
#         #Keep a boolean to get out of the loop once I find an area id for a pod id
#         hasFound = False
#         #while r < len(rows):
#         for key in dictionary:
#             if hasFound == False:
#                 latNE = dictionary[key][0]
#                 lngNE = dictionary[key][1]
#                 latSW = dictionary[key][2]
#                 lngSW = dictionary[key][3]

#                 #Checks to see if the lat and long of a pod id is withing a particular "box" with the right upper corner being
#                 #latNE, LngNE and the left lower corner being latSW, lngSW
#                 #If the pod is inside that area, assign it that area id.
#                 if float(r[1]) <= latNE and float(r[1]) >= latSW and float(r[2]) >= lngSW and float(r[2]) <= lngNE:
#                     if float(r[1]) == 0 or float(r[2]) == 0: continue

#                     #Adds a list containing [Pod id, area id] to the new_list
#                     #So new_list is essentially a list of lists
#                     new_list.append([r[0], key])

#                     #Set to true so the loop doesn't repeat again for the pod_id once area_id is found for it. Saves time.
#                     hasFound = True

#     #Write to a text file all the queries that can be used to modify the table carsharingpods to include the area id
#     #This needs to be done cause direct insertion wasn't working.
#     #Also look at the text.out file provided
#     with open('text.out', 'w+') as outFile:
#         for elem in new_list:
#             outFile.write("Update carsharingpods Set area_id={} Where pod_id={};".format(str(elem[1]), str(elem[0])) + "\n")
# Out:
# LANE COVE ROAD (SOUTHBOUND) NORTH RYDE SOUTHBOUND
# {'error_message': 'You have exceeded your daily request quota for this API.', 'results': [], 'status': 'OVER_QUERY_LIMIT'}
# LANE COVE TUNNEL LANE COVE EASTBOUND
# {'error_message': 'You have exceeded your daily request quota for this API.', 'results': [], 'status': 'OVER_QUERY_LIMIT'}
# LANE COVE TUNNEL LANE COVE WEST WESTBOUND
# {'error_message': 'You have exceeded your daily request quota for this API.', 'results': [], 'status': 'OVER_QUERY_LIMIT'}
# LANE COVE ROAD (NORTHBOUND) NORTH RYDE NORTHBOUND
# {'error_message': 'You have exceeded your daily request quota for this API.', 'results': [], 'status': 'OVER_QUERY_LIMIT'}
# LANE COVE TUNNEL LANE COVE WEST WESTBOUND
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...
